# %%
import streamlit as st
import pandas as pd
import numpy as np
import folium
from streamlit_folium import folium_static
import base64
from PIL import Image
import io
import os
import streamlit.components.v1 as components

# Configuración de página
st.set_page_config(
    page_title="Análisis de Colegios - Huancavelica y Ayacucho",
    page_icon="🏫",
    layout="wide"
)

# Función para mostrar imágenes reales (no placeholders)
def display_image(image_path):
    try:
        # Cargar la imagen real desde el sistema de archivos
        image = Image.open(image_path)
        st.image(image, caption=f"Mapa: {os.path.basename(image_path)}", use_container_width=True)
    except Exception as e:
        st.error(f"Error al cargar la imagen {image_path}: {e}")
        st.write(f"Asegúrate de que la imagen exista en la ruta: {image_path}")

# Función para cargar HTML local (para mapas dinámicos)
def display_html_file(html_path):
    try:
        # Leer el contenido del archivo HTML
        with open(html_path, 'r', encoding='utf-8') as f:
            html_data = f.read()
        
        # Mostrar el HTML utilizando el componente de HTML de Streamlit
        components.html(html_data, height=600, scrolling=True)
        
    except FileNotFoundError:
        st.error(f"No se encontró el archivo HTML: {html_path}")
        st.write(f"Por favor, verifica que el archivo existe en la ruta: {html_path}")
        
        # Crear un mapa folium básico como respaldo
        st.write("Mostrando un mapa de respaldo:")
        m = folium.Map(location=[-13.0456, -74.2178], zoom_start=8)
        folium.Marker(
            [-13.0456, -74.2178], 
            popup="Ejemplo de mapa dinámico", 
            tooltip="Punto central"
        ).add_to(m)
        folium_static(m)
    except Exception as e:
        st.error(f"Error al cargar el HTML: {e}")

# Función para crear tabla informativa
def create_info_table(data_dict):
    df = pd.DataFrame(list(data_dict.items()), columns=['Nivel Educativo', 'Total'])
    return df

# Datos para las tablas
huancavelica_data = {
    "Inicial": 1836,
    "Primaria": 1598,
    "Secundaria": 442
}

ayacucho_data = {
    "Inicial": 2300,
    "Primaria": 1518,
    "Secundaria": 563
}

total_combined_data = {
    "Inicial": 4136,
    "Primaria": 3116,
    "Secundaria": 1005
}

# APLICACIÓN PRINCIPAL
st.title("🏫 Análisis de Instituciones Educativas")
st.subheader("Huancavelica y Ayacucho - Perú")

# Crear pestañas
tab1, tab2, tab3 = st.tabs(["🗂️ Descripción de Datos", "🗺️ Mapas Estáticos", "🌍 Mapas Dinámicos"])

# PESTAÑA 1: DESCRIPCIÓN DE DATOS
with tab1:
    st.header("Descripción de Datos")
    
    # Unidad de análisis
    st.subheader("Unidad de Análisis")
    st.write("""
    Este análisis examina la distribución de instituciones educativas en los departamentos 
    de Huancavelica y Ayacucho, considerando los niveles educativos de Inicial, Primaria y Secundaria.
    """)
    
    # Tablas informativas
    col1, col2, col3 = st.columns(3)
    
    with col1:
        st.subheader("Total Combinado")
        st.table(create_info_table(total_combined_data))
    
    with col2:
        st.subheader("Huancavelica")
        st.table(create_info_table(huancavelica_data))
    
    with col3:
        st.subheader("Ayacucho")
        st.table(create_info_table(ayacucho_data))
    
    # Fuentes de datos
    st.subheader("Fuentes de Datos")
    st.write("""
    El conjunto de datos proporcionado contiene información detallada sobre diversas instituciones 
    educativas. Incluye datos como el código único de cada institución, su nombre, ubicación geográfica 
    (latitud, longitud y altitud), el nivel educativo que ofrecen, su modalidad (pública o privada) y 
    la dependencia administrativa. También se detalla la dirección física de las instituciones, 
    el código del centro poblado cercano y la fuente de las coordenadas geográficas utilizadas para su localización.
    
    Estos datos son útiles para la gestión educativa y análisis geográfico. Se realizó un merge entre los datos 
    de las instituciones educativas y un archivo de formas (shapefile) para poder elaborar los mapas estáticos 
    y dinámicos que se presentan en este análisis.
    """)

# PESTAÑA 2: MAPAS ESTÁTICOS
with tab2:
    st.header("Mapas Estáticos")
    
    # División para Huancavelica y Ayacucho
    col1, col2 = st.columns(2)
    
    with col1:
        st.subheader("Huancavelica")
        
        # Mapas estáticos de Huancavelica - Usando rutas absolutas correctas
        huancavelica_maps = [
            "C:/Users/usuario/Documents/GitHub/High-School-Access-Peru/tarea/Huancavelica_inicial.png",
            "C:/Users/usuario/Documents/GitHub/High-School-Access-Peru/tarea/Huancavelica_primaria.png",
            "C:/Users/usuario/Documents/GitHub/High-School-Access-Peru/tarea/Huancavelica_secundaria.png"
        ]
        
        for map_path in huancavelica_maps:
            level_name = os.path.basename(map_path).split('_')[-1].split('.')[0].capitalize()
            st.write(f"**{level_name}**")
            display_image(map_path)
    
    with col2:
        st.subheader("Ayacucho")
        
        # Mapas estáticos de Ayacucho - Usando rutas absolutas correctas
        ayacucho_maps = [
            "C:/Users/usuario/Documents/GitHub/High-School-Access-Peru/tarea/ayacucho_inicial.png",
            "C:/Users/usuario/Documents/GitHub/High-School-Access-Peru/tarea/ayacucho_primaria.png",
            "C:/Users/usuario/Documents/GitHub/High-School-Access-Peru/tarea/ayacucho_secundaria.png"
        ]
        
        for map_path in ayacucho_maps:
            level_name = os.path.basename(map_path).split('_')[-1].split('.')[0].capitalize()
            st.write(f"**{level_name}**")
            display_image(map_path)

# PESTAÑA 3: MAPAS DINÁMICOS
with tab3:
    st.header("Mapas Dinámicos")
    
    # Mapa dinámico de proximidad para Huancavelica
    st.subheader("Mapa de Proximidad - Huancavelica")
    
    html_path = "C:/Users/usuario/Documents/GitHub/High-School-Access-Peru/tarea/mapa_proximidad_huancavelica.html"
    display_html_file(html_path)
    
    st.write("""
    Este mapa interactivo muestra la distribución espacial de las instituciones educativas en Huancavelica, 
    permitiendo analizar la proximidad entre centros educativos y áreas pobladas.
    
    Para navegar por el mapa:
    - Utiliza el zoom para acercarte o alejarte
    - Haz clic sobre los marcadores para ver información detallada
    - Puedes arrastrar el mapa para explorar diferentes áreas
    """)

# Agregar una sección para reportar problemas
st.sidebar.header("Información de Depuración")
st.sidebar.write("Si encuentras problemas con los mapas:")
st.sidebar.write("1. Verifica que las rutas de los archivos sean correctas")
st.sidebar.write("2. Asegúrate de que los archivos existan en las ubicaciones especificadas")
st.sidebar.write("3. Revisa los permisos de acceso a los archivos")

# Mostrar las rutas actuales para facilitar la depuración
if st.sidebar.checkbox("Mostrar rutas de archivos"):
    st.sidebar.subheader("Rutas de mapas estáticos:")
    for path in huancavelica_maps + ayacucho_maps:
        st.sidebar.code(path)
    st.sidebar.subheader("Ruta de mapa dinámico:")
    st.sidebar.code(html_path)
# Out:
# 2025-04-30 22:50:55.421 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:55.987 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:55.989 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.156
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\usuario\anaconda3\envs\acceso-colegios\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-30 22:50:56.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:56.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:58.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:58.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:58.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:58.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:58.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:58.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:50:58.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:00.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:00.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:00.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:00.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:00.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:00.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:00.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:02.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:04.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:04.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:04.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:04.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:04.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:04.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:04.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:07.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:07.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:07.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:07.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:07.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:07.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 22:51:09.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#!jupyter nbconvert --to script app_streamlit_fixed.ipynb
